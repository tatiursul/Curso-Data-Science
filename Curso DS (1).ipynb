# %%
import pandas as pd
import numpy as np

# %%
Encuestas_2016 = pd.read_csv('C:\\Users\\HP\\Downloads\\presidential_polls_2016_fivethirtyeight.csv')

# %%
Encuestas_2016.head(1000)
# Out:
#      cycle     branch        type                        matchup forecastdate  \
# 0     2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 1     2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 2     2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 3     2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 4     2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# ..     ...        ...         ...                            ...          ...
# 995   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 996   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 997   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 998   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 999   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
#
# ...

# %%
Encuestas_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12624 entries, 0 to 12623
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cycle             12624 non-null  int64
#  1   branch            12624 non-null  object
#  2   type              12624 non-null  object
#  3   matchup           12624 non-null  object
#  4   forecastdate      12624 non-null  object
#  5   state             12624 non-null  object
#  6   startdate         12624 non-null  object
#  7   enddate           12624 non-null  object
#  8   pollster          12624 non-null  object
#  9   grade             11337 non-null  object
#  10  samplesize        12621 non-null  float64
#  11  population        12624 non-null  object
#  12  poll_wt           12624 non-null  float64
#  13  rawpoll_clinton   12624 non-null  float64
#  14  rawpoll_trump     12624 non-null  float64
#  15  rawpoll_johnson   8397 non-null   float64
# ...

# %%
Netflix= pd.read_csv('C:\\Users\\HP\\Downloads\\name_basics movies.tsv', sep='\t', low_memory=False)

# %%
Netflix.head(1000)
# Out:
#         tconst titleType                                       primaryTitle  \
# 0    tt0000001     short                                         Carmencita
# 1    tt0000002     short                             Le clown et ses chiens
# 2    tt0000003     short                                     Pauvre Pierrot
# 3    tt0000004     short                                        Un bon bock
# 4    tt0000005     short                                   Blacksmith Scene
# ..         ...       ...                                                ...
# 995  tt0001007     movie                       La primera y segunda casetas
# 996  tt0001008     short                          The Prince and the Pauper
# 997  tt0001009     short             Princess Nicotine; or, the Smoke Fairy
# 998  tt0001010     movie  Protección de un convoy de víveres en el puent...
# 999  tt0001011     short                                   The Prussian Spy
#
# ...

# %%
df_movies = Netflix[Netflix['titleType']=='movie']

# %%
Ratings= pd.read_csv('C:\\Users\\HP\\Downloads\\rating.tsv', sep='\t', low_memory=False)

# %%
Ratings.head(1000)
# Out:
#         tconst  averageRating  numVotes
# 0    tt0000001            5.7      1816
# 1    tt0000002            6.0       233
# 2    tt0000003            6.5      1572
# 3    tt0000004            6.1       151
# 4    tt0000005            6.2      2391
# ..         ...            ...       ...
# 995  tt0002130            7.0      2637
# 996  tt0002132            5.5        13
# 997  tt0002133            5.8       189
# 998  tt0002136            5.7        77
# 999  tt0002139            5.6        17
#
# [1000 rows x 3 columns]

# %%
df_merge = pd.merge(df_movies, Ratings, how='left', on='tconst')

# %%
df_merge.dropna()
# Out:
#            tconst titleType                 primaryTitle  \
# 0       tt0000502     movie                     Bohemios
# 1       tt0000574     movie  The Story of the Kelly Gang
# 2       tt0000591     movie             The Prodigal Son
# 3       tt0000615     movie           Robbery Under Arms
# 4       tt0000630     movie                       Hamlet
# ...           ...       ...                          ...
# 587742  tt9916190     movie                    Safeguard
# 587743  tt9916270     movie     Il talento del calabrone
# 587744  tt9916362     movie                        Coven
# 587745  tt9916428     movie          The Secret of China
# 587746  tt9916538     movie          Kuambil Lagi Hatiku
#
#                        originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                           Bohemios       0      1905      \N            100
# 1        The Story of the Kelly Gang       0      1906      \N             70
# ...

# %%
df_merge.head(1000)
# Out:
#         tconst titleType                          primaryTitle  \
# 0    tt0000502     movie                              Bohemios
# 1    tt0000574     movie           The Story of the Kelly Gang
# 2    tt0000591     movie                      The Prodigal Son
# 3    tt0000615     movie                    Robbery Under Arms
# 4    tt0000630     movie                                Hamlet
# ..         ...       ...                                   ...
# 995  tt0005162     movie             The Crown Prince's Double
# 996  tt0005163     movie                               The Cub
# 997  tt0005164     movie                      Cuentos baturros
# 998  tt0005166     movie                       The Cup of Life
# 999  tt0005167     movie  The Curious Conduct of Judge Legarde
#
#                             originalTitle isAdult startYear endYear  \
# 0                                Bohemios       0      1905      \N
# 1             The Story of the Kelly Gang       0      1906      \N
# ...

# %%
df_merge.sort_values(['numVotes'], ascending=[False])
# Out:
#            tconst titleType  \
# 77592   tt0111161     movie
# 209187  tt0468569     movie
# 311026  tt1375666     movie
# 91502   tt0137523     movie
# 77429   tt0110912     movie
# ...           ...       ...
# 587748  tt9916622     movie
# 587749  tt9916680     movie
# 587750  tt9916706     movie
# 587751  tt9916730     movie
# 587752  tt9916754     movie
#
#                                              primaryTitle  \
# 77592                            The Shawshank Redemption
# 209187                                    The Dark Knight
# 311026                                          Inception
# 91502                                          Fight Club
# 77429                                        Pulp Fiction
# ...                                                   ...
# 587748        Rodolpho Teóphilo - O Legado de um Pioneiro
# 587749  De la ilusión al desconcierto: cine colombiano...
# 587750                                    Dankyavar Danka
# ...

# %%
df_merge.count()
# Out:
# tconst            587753
# titleType         587753
# primaryTitle      587753
# originalTitle     587753
# isAdult           587753
# startYear         587753
# endYear           587753
# runtimeMinutes    587753
# genres            587753
# averageRating     268457
# numVotes          268457
# dtype: int64

# %%
Crew = pd.read_csv('C:\\Users\\HP\\Downloads\\crew.tsv', sep='\t', low_memory=False)

# %%
Crew.head()
# Out:
#       tconst  directors writers
# 0  tt0000001  nm0005690      \N
# 1  tt0000002  nm0721526      \N
# 2  tt0000003  nm0721526      \N
# 3  tt0000004  nm0721526      \N
# 4  tt0000005  nm0005690      \N

# %%
df_merge_2 = pd.merge(df_merge, Crew, how='left', on='tconst')

# %%
df_merge_2.head()
# Out:
#       tconst titleType                 primaryTitle  \
# 0  tt0000502     movie                     Bohemios
# 1  tt0000574     movie  The Story of the Kelly Gang
# 2  tt0000591     movie             The Prodigal Son
# 3  tt0000615     movie           Robbery Under Arms
# 4  tt0000630     movie                       Hamlet
#
#                  originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                     Bohemios       0      1905      \N            100
# 1  The Story of the Kelly Gang       0      1906      \N             70
# 2            L'enfant prodigue       0      1907      \N             90
# 3           Robbery Under Arms       0      1907      \N             \N
# 4                       Amleto       0      1908      \N             \N
#
#                        genres  averageRating  numVotes  directors  \
# 0                          \N            4.5      14.0  nm0063413
# 1  Action,Adventure,Biography            6.1     693.0  nm0846879
# ...

# %%
Nombres = pd.read_csv('C:\\Users\\HP\\Downloads\\names.tsv', sep='\t', low_memory=False)

# %%
Nombres.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
#
#                             knownForTitles
# 0  tt0031983,tt0072308,tt0050419,tt0053137
# 1  tt0071877,tt0117057,tt0038355,tt0037382
# 2  tt0056404,tt0054452,tt0057345,tt0049189
# 3  tt0077975,tt0078723,tt0072562,tt0080455
# 4  tt0083922,tt0050976,tt0050986,tt0060827

# %%
df_merge_3 = pd.merge(df_merge_2, Nombres, how='left', left_on='directors', right_on='nconst')

# %%
df_merge_3.head(1000)
# Out:
#         tconst titleType                          primaryTitle  \
# 0    tt0000502     movie                              Bohemios
# 1    tt0000574     movie           The Story of the Kelly Gang
# 2    tt0000591     movie                      The Prodigal Son
# 3    tt0000615     movie                    Robbery Under Arms
# 4    tt0000630     movie                                Hamlet
# ..         ...       ...                                   ...
# 995  tt0005162     movie             The Crown Prince's Double
# 996  tt0005163     movie                               The Cub
# 997  tt0005164     movie                      Cuentos baturros
# 998  tt0005166     movie                       The Cup of Life
# 999  tt0005167     movie  The Curious Conduct of Judge Legarde
#
#                             originalTitle isAdult startYear endYear  \
# 0                                Bohemios       0      1905      \N
# 1             The Story of the Kelly Gang       0      1906      \N
# ...

# %%
df_final = df_merge_3.sort_values(['numVotes'], ascending=[False])

# %%
df_final.head(10)
# Out:
#            tconst titleType  \
# 77592   tt0111161     movie
# 209187  tt0468569     movie
# 311026  tt1375666     movie
# 91502   tt0137523     movie
# 77429   tt0110912     movie
# 76763   tt0109830     movie
# 89362   tt0133093     movie
# 82801   tt0120737     movie
# 104217  tt0167260     movie
# 50055   tt0068646     movie
#
#                                              primaryTitle  \
# 77592                            The Shawshank Redemption
# 209187                                    The Dark Knight
# 311026                                          Inception
# 91502                                          Fight Club
# 77429                                        Pulp Fiction
# 76763                                        Forrest Gump
# 89362                                          The Matrix
# 82801   The Lord of the Rings: The Fellowship of the Ring
# 104217      The Lord of the Rings: The Return of the King
# 50055                                       The Godfather
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.set()

# %%
df_filtrado = df_final.head(10)
df_filtrado
# Out:
#            tconst titleType  \
# 77592   tt0111161     movie
# 209187  tt0468569     movie
# 311026  tt1375666     movie
# 91502   tt0137523     movie
# 77429   tt0110912     movie
# 76763   tt0109830     movie
# 89362   tt0133093     movie
# 82801   tt0120737     movie
# 104217  tt0167260     movie
# 50055   tt0068646     movie
#
#                                              primaryTitle  \
# 77592                            The Shawshank Redemption
# 209187                                    The Dark Knight
# 311026                                          Inception
# 91502                                          Fight Club
# 77429                                        Pulp Fiction
# 76763                                        Forrest Gump
# 89362                                          The Matrix
# 82801   The Lord of the Rings: The Fellowship of the Ring
# 104217      The Lord of the Rings: The Return of the King
# 50055                                       The Godfather
#
# ...

# %%
sns.barplot (x = "primaryName", y = "averageRating", data = df_filtrado)
# Out:
# <AxesSubplot:xlabel='primaryName', ylabel='averageRating'>
